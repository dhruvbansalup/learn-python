# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def decode(root,ciphertext):
    result=""
    temp=root
    for i in ciphertext:
        temp = temp.left if i=='0' else temp.right;
        if temp.left is None:
            result+=temp.symbol
            temp=root
    return result
